# %%
using Pkg

# %%
Pkg.add("CSV")
Pkg.add("HTTP")
Pkg.add("Convex")
Pkg.add("SCS")
Pkg.add("DataFrames")
Pkg.add("DataStructures")
Pkg.add("Interpolations")
Pkg.add("JSON3")
Pkg.add("StringEncodings")

# %%
Pkg.add("Plots")
# Out:
#     Updating registry at `C:\Users\hmills1\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed GR_jll ─────────────────────── v0.73.16+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed JpegTurbo_jll ──────────────── v3.1.1+0
#    Installed libfdk_aac_jll ─────────────── v2.0.3+0
#    Installed Opus_jll ───────────────────── v1.3.3+0
#    Installed Libmount_jll ───────────────── v2.41.0+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Unitful ────────────────────── v1.22.1
#    Installed Measures ───────────────────── v0.3.2
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Contour ────────────────────── v0.6.3
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.1+1
#    Installed Xorg_xcb_util_image_jll ────── v0.4.0+1
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed ColorSchemes ───────────────── v3.29.0
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Xorg_xcb_util_jll ──────────── v0.4.0+1
#    Installed Cairo_jll ──────────────────── v1.18.4+0
#    Installed Fontconfig_jll ─────────────── v2.16.0+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed FFMPEG ─────────────────────── v0.4.2
#    Installed Pango_jll ──────────────────── v1.56.1+0
#    Installed GR ─────────────────────────── v0.73.16
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.0+1
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed xkbcommon_jll ──────────────── v1.8.1+0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed HarfBuzz_jll ───────────────── v8.5.0+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed StatsAPI ───────────────────── v1.7.0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed Colors ─────────────────────── v0.13.1
#    Installed libpng_jll ─────────────────── v1.6.48+0
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed mtdev_jll ──────────────────── v1.1.6+0
#    Installed StatsBase ──────────────────── v0.34.5
#    Installed libaom_jll ─────────────────── v3.11.0+0
#    Installed gperf_jll ──────────────────── v3.3.0+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed Scratch ────────────────────── v1.2.1
#    Installed eudev_jll ──────────────────── v3.2.9+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Plots ──────────────────────── v1.40.13
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.4+0
#    Installed Expat_jll ──────────────────── v2.6.5+0
#    Installed Libtiff_jll ────────────────── v4.7.1+0
#    Installed Format ─────────────────────── v1.3.7
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Libffi_jll ─────────────────── v3.2.2+2
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libinput_jll ───────────────── v1.18.0+0
#    Installed libevdev_jll ───────────────── v1.11.0+0
#    Installed Ogg_jll ────────────────────── v1.3.5+1
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed AliasTables ────────────────── v1.1.3
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed Wayland_protocols_jll ──────── v1.36.0+0
#    Installed Libuuid_jll ────────────────── v2.41.0+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.9+1
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed libass_jll ─────────────────── v0.15.2+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed XML2_jll ───────────────────── v2.13.6+1
#    Installed Gettext_jll ────────────────── v0.21.0+0
#    Installed Wayland_jll ────────────────── v1.21.0+2
#    Installed Latexify ───────────────────── v0.16.7
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed FFMPEG_jll ─────────────────── v4.4.4+1
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed Xorg_libXfixes_jll ─────────── v6.0.1+0
#    Installed LAME_jll ───────────────────── v3.100.2+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+0
#    Installed Glib_jll ───────────────────── v2.82.4+0
#    Installed libvorbis_jll ──────────────── v1.3.7+2
#    Installed Qt6Base_jll ────────────────── v6.8.2+1
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed UnitfulLatexify ────────────── v1.6.4
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Project.toml`
#   [91a5bcdd] + Plots v1.40.13
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [35d6a980] + ColorSchemes v3.29.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.16
#   [42e2da0e] + Grisu v1.0.2
#   [1019f520] + JLFzf v0.1.11
#   [23fbe1c1] + Latexify v0.16.7
#   [442fdcdd] + Measures v0.3.2
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.13
#   [43287f4e] + PtrArrays v1.3.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [860ef19b] + StableRNGs v1.0.3
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.5
#   [62fd8b95] + TensorCore v0.1.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.22.1
#   [45397f5d] + UnitfulLatexify v1.6.4
#   [41fe7b60] + Unzip v0.2.0
# ⌃ [83423d85] + Cairo_jll v1.18.4+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.16.0+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.16+0
#   [78b55507] + Gettext_jll v0.21.0+0
# ⌃ [7746bdde] + Glib_jll v2.82.4+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+2
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [4b2f31a3] + Libmount_jll v2.41.0+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.41.0+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [91d4177d] + Opus_jll v1.3.3+0
#   [36c8627f] + Pango_jll v1.56.1+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+1
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+0
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
# ⌃ [a2964d1f] + Wayland_jll v1.21.0+2
#   [2381bf8a] + Wayland_protocols_jll v1.36.0+0
# ⌅ [02c8fc9c] + XML2_jll v2.13.6+1
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.1+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.9+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [1a1c6b14] + gperf_jll v3.3.0+0
#   [a4ae2306] + libaom_jll v3.11.0+0
#   [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.3+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.48+0
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.6+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.8.1+0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#    4963.0 ms  ✓ TensorCore
#    4937.2 ms  ✓ StatsAPI
#    5141.7 ms  ✓ Contour
#    5106.3 ms  ✓ StableRNGs
#    5209.2 ms  ✓ PtrArrays
#    5449.8 ms  ✓ Measures
#    5473.4 ms  ✓ DelimitedFiles
#    5665.6 ms  ✓ Unzip
#    5810.3 ms  ✓ Grisu
#    6129.2 ms  ✓ Format
#    6235.2 ms  ✓ UnicodeFun
#    4840.7 ms  ✓ Scratch
#    5172.1 ms  ✓ Graphite2_jll
#    5118.5 ms  ✓ Libmount_jll
#    5081.1 ms  ✓ EpollShim_jll
#    5097.3 ms  ✓ Xorg_libICE_jll
#    5138.3 ms  ✓ Xorg_libXau_jll
#    5176.8 ms  ✓ libpng_jll
#    5038.1 ms  ✓ libfdk_aac_jll
#    4919.4 ms  ✓ LAME_jll
#    6485.5 ms  ✓ RecipesBase
#    5301.1 ms  ✓ Pixman_jll
#    5002.2 ms  ✓ LERC_jll
#    5012.1 ms  ✓ fzf_jll
#    5141.6 ms  ✓ JpegTurbo_jll
#    5186.1 ms  ✓ XZ_jll
#    5150.5 ms  ✓ Ogg_jll
#    5147.4 ms  ✓ mtdev_jll
#    5245.7 ms  ✓ gperf_jll
#    5190.6 ms  ✓ Xorg_libXdmcp_jll
#    4977.1 ms  ✓ x265_jll
#    5300.3 ms  ✓ libaom_jll
#    5441.2 ms  ✓ x264_jll
#    5527.3 ms  ✓ Zstd_jll
#    5392.7 ms  ✓ Expat_jll
#    5450.0 ms  ✓ LZO_jll
#    5415.3 ms  ✓ Opus_jll
#    5433.7 ms  ✓ Xorg_xtrans_jll
#    5389.6 ms  ✓ libevdev_jll
#    5355.4 ms  ✓ Wayland_protocols_jll
#    5617.7 ms  ✓ Libffi_jll
#    6007.8 ms  ✓ Libuuid_jll
#    6317.9 ms  ✓ FriBidi_jll
#    6425.6 ms  ✓ FreeType2_jll
#    6055.9 ms  ✓ Showoff
#    6585.5 ms  ✓ XML2_jll
#    6699.6 ms  ✓ AliasTables
#    6265.8 ms  ✓ RelocatableFolders
#    6211.8 ms  ✓ Xorg_libSM_jll
#   24212.2 ms  ✓ Unitful
#    8515.6 ms  ✓ FixedPointNumbers
#    9250.6 ms  ✓ Latexify
#    5993.5 ms  ✓ JLFzf
#    5378.0 ms  ✓ eudev_jll
#    5907.6 ms  ✓ libvorbis_jll
#    5518.4 ms  ✓ Xorg_libxcb_jll
#    5337.5 ms  ✓ Dbus_jll
#    5081.0 ms  ✓ Wayland_jll
#    6163.2 ms  ✓ Gettext_jll
#    7042.8 ms  ✓ Fontconfig_jll
#    7585.2 ms  ✓ Libtiff_jll
#    8019.7 ms  ✓ StatsBase
#    7252.4 ms  ✓ Interpolations → InterpolationsUnitfulExt
#    5592.0 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    5119.2 ms  ✓ libinput_jll
#    4920.5 ms  ✓ Xorg_xcb_util_jll
#    5836.0 ms  ✓ Latexify → SparseArraysExt
#    4874.8 ms  ✓ Xorg_libX11_jll
#    7235.1 ms  ✓ ColorTypes
#    7071.1 ms  ✓ UnitfulLatexify
#    6423.4 ms  ✓ Glib_jll
#    5101.6 ms  ✓ Xorg_xcb_util_image_jll
#    5235.6 ms  ✓ Xorg_xcb_util_keysyms_jll
#    5311.3 ms  ✓ Xorg_xcb_util_wm_jll
#    5450.6 ms  ✓ Xorg_xcb_util_renderutil_jll
#    5183.5 ms  ✓ Xorg_libXrender_jll
#    5293.9 ms  ✓ Xorg_libXext_jll
#    5409.8 ms  ✓ Xorg_libXfixes_jll
#    5127.2 ms  ✓ Xorg_libxkbfile_jll
#    7318.2 ms  ✓ Latexify → DataFramesExt
#    7180.0 ms  ✓ ColorVectorSpace
#    5018.4 ms  ✓ Xorg_xcb_util_cursor_jll
#    5295.8 ms  ✓ Xorg_libXrandr_jll
#    5431.4 ms  ✓ Xorg_libXinerama_jll
#    5478.6 ms  ✓ Libglvnd_jll
#    5540.1 ms  ✓ Xorg_libXcursor_jll
#    5595.6 ms  ✓ Xorg_libXi_jll
#    5433.2 ms  ✓ Xorg_xkbcomp_jll
#    8986.6 ms  ✓ Colors
#    4997.1 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    9027.3 ms  ✓ Cairo_jll
#    3530.0 ms  ✓ Xorg_xkeyboard_config_jll
#    6153.2 ms  ✓ ColorSchemes
#    3277.4 ms  ✓ xkbcommon_jll
#    5318.0 ms  ✓ HarfBuzz_jll
#    3322.5 ms  ✓ Vulkan_Loader_jll
#    5156.2 ms  ✓ libass_jll
#    5258.1 ms  ✓ Pango_jll
#    9816.4 ms  ✓ PlotUtils
#    7544.2 ms  ✓ Qt6Base_jll
#    3942.7 ms  ✓ libdecor_jll
#    3634.2 ms  ✓ GLFW_jll
#    6753.3 ms  ✓ PlotThemes
#    9437.9 ms  ✓ FFMPEG_jll
#    7154.7 ms  ✓ RecipesPipeline
#    7725.5 ms  ✓ Qt6ShaderTools_jll
#    6409.4 ms  ✓ FFMPEG
#    4880.9 ms  ✓ Qt6Declarative_jll
#    7770.4 ms  ✓ GR_jll
#    2865.3 ms  ✓ Qt6Wayland_jll
#    8565.9 ms  ✓ GR
#   42010.8 ms  ✓ Plots
#    8484.4 ms  ✓ Plots → UnitfulExt
#    7116.0 ms  ✓ Plots → IJuliaExt
#   114 dependencies successfully precompiled in 153 seconds. 111 already precompiled.

# %%
Pkg.add("StatsPlots")
# Out:
#    Resolving package versions...
#    Installed IntelOpenMP_jll ───────── v2025.0.4+0
#    Installed PDMats ────────────────── v0.11.35
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed OpenSSL ───────────────── v1.5.0
#    Installed StatsFuns ─────────────── v1.5.0
#    Installed Distances ─────────────── v0.10.12
#    Installed NearestNeighbors ──────── v0.4.21
#    Installed FFTW ──────────────────── v1.8.1
#    Installed Rmath_jll ─────────────── v0.5.1+0
#    Installed oneTBB_jll ────────────── v2022.0.0+0
#    Installed MKL_jll ───────────────── v2025.0.1+1
#    Installed AbstractFFTs ──────────── v1.5.0
#    Installed StatsPlots ────────────── v0.15.7
#    Installed JSON3 ─────────────────── v1.14.3
#    Installed Clustering ────────────── v0.15.8
#    Installed FFTW_jll ──────────────── v3.3.11+0
#    Installed OrderedCollections ────── v1.8.1
#    Installed KernelDensity ─────────── v0.6.9
#    Installed MultivariateStats ─────── v0.10.3
#    Installed Widgets ───────────────── v0.6.7
#    Installed Interpolations ────────── v0.15.1
#    Installed Rmath ─────────────────── v0.8.0
#    Installed TableOperations ───────── v1.2.0
#    Installed Arpack_jll ────────────── v3.5.1+1
#    Installed MathOptInterface ──────── v1.40.1
#    Installed FillArrays ────────────── v1.13.0
#    Installed QuadGK ────────────────── v2.11.2
#    Installed Arpack ────────────────── v0.5.4
#    Installed Observables ───────────── v0.5.5
#    Installed Distributions ─────────── v0.25.120
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Project.toml`
# ⌅ [a98d9a8b] ↓ Interpolations v0.16.0 ⇒ v0.15.1
#   [0f8b85d8] ↑ JSON3 v1.14.2 ⇒ v1.14.3
#   [f3b207a7] + StatsPlots v0.15.7
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [7d9fca2a] + Arpack v0.5.4
#   [aaaa29a8] + Clustering v0.15.8
#   [b4f34e82] + Distances v0.10.12
#   [31c24e10] + Distributions v0.25.120
#   [7a1cc6ca] + FFTW v1.8.1
#   [1a297f60] + FillArrays v1.13.0
#   [34004b35] + HypergeometricFunctions v0.3.28
# ⌅ [a98d9a8b] ↓ Interpolations v0.16.0 ⇒ v0.15.1
#   [0f8b85d8] ↑ JSON3 v1.14.2 ⇒ v1.14.3
#   [5ab0869b] + KernelDensity v0.6.9
#   [b8f27783] ↑ MathOptInterface v1.40.0 ⇒ v1.40.1
#   [6f286f6a] + MultivariateStats v0.10.3
#   [b8a86587] + NearestNeighbors v0.4.21
#   [510215fc] + Observables v0.5.5
#   [4d8831e6] ↑ OpenSSL v1.4.3 ⇒ v1.5.0
#   [bac558e1] ↑ OrderedCollections v1.8.0 ⇒ v1.8.1
#   [90014a1f] + PDMats v0.11.35
#   [1fd47b50] + QuadGK v2.11.2
#   [79098fc4] + Rmath v0.8.0
#   [4c63d2b9] + StatsFuns v1.5.0
#   [f3b207a7] + StatsPlots v0.15.7
#   [ab02a1b2] + TableOperations v1.2.0
#   [cc8bc4a8] + Widgets v0.6.7
# ⌅ [68821587] + Arpack_jll v3.5.1+1
#   [f5851436] + FFTW_jll v3.3.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [4af54fe1] + LazyArtifacts
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling packages...
#    5460.8 ms  ✓ AbstractFFTs
#    5274.2 ms  ✓ OrderedCollections
#    5479.3 ms  ✓ Observables
#    5412.1 ms  ✓ Rmath_jll
#    5655.7 ms  ✓ SuiteSparse
#    5896.7 ms  ✓ FillArrays
#    5798.8 ms  ✓ FFTW_jll
#    5917.9 ms  ✓ oneTBB_jll
#    6079.0 ms  ✓ IntelOpenMP_jll
#    6172.2 ms  ✓ Arpack_jll
#    6272.0 ms  ✓ Distances
#    5648.6 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    5743.0 ms  ✓ Tables
#    6259.2 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    5773.9 ms  ✓ Rmath
#    6870.5 ms  ✓ HypergeometricFunctions
#    7260.1 ms  ✓ OpenSSL
#    6390.2 ms  ✓ Widgets
#    7022.1 ms  ✓ DataStructures
#    7655.8 ms  ✓ Interpolations
#    8472.2 ms  ✓ Latexify
#   10947.2 ms  ✓ JSON3
#    6112.5 ms  ✓ PDMats
#    5591.7 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    5878.0 ms  ✓ Arpack
#    5995.0 ms  ✓ Distances → DistancesSparseArraysExt
#    5966.0 ms  ✓ TableOperations
#    7912.8 ms  ✓ StatsFuns
#    5337.9 ms  ✓ SortingAlgorithms
#    9710.9 ms  ✓ MKL_jll
#    6127.7 ms  ✓ QuadGK
#    6677.0 ms  ✓ Interpolations → InterpolationsUnitfulExt
#    5999.6 ms  ✓ Latexify → SparseArraysExt
#    6950.2 ms  ✓ UnitfulLatexify
#    5810.4 ms  ✓ FillArrays → FillArraysStatisticsExt
#    6042.0 ms  ✓ FillArrays → FillArraysPDMatsExt
#    5995.4 ms  ✓ Distances → DistancesChainRulesCoreExt
#   17612.7 ms  ✓ CSV
#    8444.1 ms  ✓ NearestNeighbors
#    8389.3 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    9286.0 ms  ✓ StatsBase
#   20234.6 ms  ✓ HTTP
#   22549.0 ms  ✓ PrettyTables
#   12660.4 ms  ✓ FFTW
#    6884.3 ms  ✓ Clustering
#   10356.4 ms  ✓ Distributions
#    6517.9 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    6872.5 ms  ✓ Distributions → DistributionsTestExt
#    7385.8 ms  ✓ MultivariateStats
#   37707.8 ms  ✓ MathOptInterface
#    8358.1 ms  ✓ KernelDensity
#   10050.7 ms  ✓ Convex
#   34220.7 ms  ✓ DataFrames
#    5508.4 ms  ✓ Latexify → DataFramesExt
#   23260.2 ms  ✓ SCS
#   51215.0 ms  ✓ Plots
#    7784.2 ms  ✓ Plots → UnitfulExt
#    7005.2 ms  ✓ Plots → IJuliaExt
#   10264.8 ms  ✓ StatsPlots
#   59 dependencies successfully precompiled in 108 seconds. 202 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# └

# %%
Pkg.add("HypothesisTests")
# Out:
#     Updating registry at `C:\Users\hmills1\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed ConstructionBase ─ v1.5.8
#    Installed Accessors ──────── v0.1.42
#    Installed CompositionsBase ─ v0.1.2
#    Installed Combinatorics ──── v1.0.3
#    Installed InverseFunctions ─ v0.1.17
#    Installed HypothesisTests ── v0.11.5
#    Installed CommonSolve ────── v0.2.4
#    Installed Roots ──────────── v2.2.7
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Project.toml`
#   [09f84164] + HypothesisTests v0.11.5
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.42
#   [861a8166] + Combinatorics v1.0.3
#   [38540f10] + CommonSolve v0.2.4
#   [a33af91c] + CompositionsBase v0.1.2
#   [187b0558] + ConstructionBase v1.5.8
#   [09f84164] + HypothesisTests v0.11.5
#   [3587e190] + InverseFunctions v0.1.17
#   [f2b01f46] + Roots v2.2.7
# Precompiling packages...
#    3819.2 ms  ✓ CommonSolve
#    3948.4 ms  ✓ CompositionsBase
#    3932.9 ms  ✓ ConstructionBase
#    5284.2 ms  ✓ Combinatorics
#    5502.8 ms  ✓ InverseFunctions
#    3005.9 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    3113.6 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    3766.9 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    3731.1 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    3831.3 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    4008.2 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    4268.6 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#    4218.8 ms  ✓ Unitful → InverseFunctionsUnitfulExt
#    3281.2 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    4266.2 ms  ✓ Accessors
#    3030.6 ms  ✓ Accessors → LinearAlgebraExt
#    3574.8 ms  ✓ Accessors → UnitfulExt
#    3704.4 ms  ✓ Accessors → StaticArraysExt
#    5107.5 ms  ✓ Roots
#    3411.6 ms  ✓ Roots → RootsChainRulesCoreExt
#    3614.0 ms  ✓ Roots → RootsForwardDiffExt
#    4940.3 ms  ✓ HypothesisTests
#   22 dependencies successfully precompiled in 39 seconds. 261 already precompiled.

# %%
Pkg.add("KernelDensity")
# Out:
#     Updating registry at `C:\Users\hmills1\.julia\registries\General.toml`
#    Resolving package versions...
#     Updating `C:\Users\hmills1\.julia\environments\v1.10\Project.toml`
#   [5ab0869b] + KernelDensity v0.6.9
#   No Changes to `C:\Users\hmills1\.julia\environments\v1.10\Manifest.toml`
