# %%
using CSV
using DataFrames
using DataStructures: OrderedDict
using HTTP
using JSON3

include("census_vars.jl");
include("secrets.jl")

ENV["census_key"] = census_key;

# %%
function format_ucgid(;agg="tract", state="", comp="Not a geographic component")
    if state != ""
        return "pseudo(04000$(geographic_components[comp])US$(states[state])\$$(geographies[agg])0000)"
    end
    return "pseudo(01000$(geographic_components[comp])US\$$(geographies[agg])0000)"
end

function query_census(surv, var; agg="county", state="")
    if var[1] == 'D'
        url = "https://api.census.gov/data/$surv/profile"
    elseif var[1] == 'S'
        url = "https://api.census.gov/data/$surv/subject"
    else
        url = "https://api.census.gov/data/$surv"
    end
    
    ucgid = format_ucgid(agg=agg, state=state)
    query = Dict([
        ("key", ENV["census_key"]),
        ("get", join(("NAME", var), ",")),
        ("ucgid", ucgid)
    ])

    println(var)
    println(url)
    println(query)
    println()
    
    r = HTTP.get(
        url;
        query = query
    )
    
    body = JSON3.read(r.body)
    header, data = body[1], body[2:end]
    
    df = OrderedDict{Symbol, Vector}()
    for (i, col_name) in enumerate(header)
        df[Symbol(col_name)] = [row[i] for row in data]
    end

    sleep(5)
    
    return DataFrame(df);
end
# Out:
# query_census (generic function with 1 method)

# %%
surv_dec = "2020/dec/dhc"
vars_dec = [
    # rurality
    "Rural" => "H2_003N"
    "Urban" => "H2_002N"
    "Urban + Rural" => "H2_001N"
]

surv_acs = "2023/acs/acs5"
vars_acs = [
    "TotalPopulation" => "B01001_001E"
    
    # Single-Parent Households
    "Male led Household with childeren" => "B11005_006E"
    "Female led Household with childeren" => "B11005_007E"
    # Nonfamilty household with child
    "NonFamily Household with childeren" => "B11005_008E"
    "Households with childeren" => "B11005_002E"

    # youth not in school
    "Male 16-19 no HS" => "B14005_012E"
    "Female 16-19 no HS" => "B14005_026E"
    "Female + Male 16-19" => "B14005_001E"

    # Pay Gap Sex
    "Male median earnings" => "B20001_002E"
    "Female median earnings" => "B20001_023E"

    # Pay Gap Race
    "White median earnings" => "B20017A_001E"
    "Black median earnings" => "B20017B_001E"

    # Housing Gap
    "Median House Price" => "B19013_001E"
    "Median Salary" => "B25077_001E"

    "Unemployment Rate" => "S2301_C04_001E"
    "Owner Occupied Housing" => "DP04_0046PE"

    #white collar jobs
    "White collar workers" => "C24060_002E"
    "Total workers" => "C24060_001E"

    # SNAP
    "Total Households" => "B22002_001E"
    "Total Households w/ SNAP" => "B22002_002E"
    "Total Households w/ SNAP + childeren" => "B22002_003E"
    "Total Households w/ SNAP + elders" => "B22001_003E"

    #tech
    "Households w/o Internet" => "B28002_013E"
    "Households w/ Broadband Internet" => "B28002_004E"
    "Households w/ Smartphone" => "B28010_005E"

    # char
    "Households w/o Car" => "DP04_0058E"
    "Households w/o Complete Plumbing" => "DP04_0073PE"
    "Households w/o Complete Kitchen" => "DP04_0074E"
    
    # transport
    "Over 60 min commuting" => "S0801_C01_045E"
    "WFH" => "S0801_C01_013E"
    "Public Transit to Work" => "S0801_C01_009E"
    "Walked to Work" => "S0801_C01_010E"
    "Biked to Work" => "S0801_C01_011E"
    "Total Workers" => "S0801_C01_001E"
];

# %%
dfs = [
    [query_census(surv_acs, var, agg="county")[!, ["ucgid", "NAME", var]] for (_, var) in vars_acs];
    [query_census(surv_dec, var, agg="county")[!, ["ucgid", "NAME", var]] for (_, var) in vars_dec]
]

df = dfs[1]
for next_df in dfs[2:end]
    leftjoin!(df, next_df, on=["NAME", "ucgid"])
end

fname = "raw_data/census/census_data_county_raw.csv"
CSV.write(fname, df)
# Out:
# B01001_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B01001_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_006E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_006E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_007E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_007E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_008E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_008E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B14005_012E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_012E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B14005_026E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_026E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B14005_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B20001_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B20001_023E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_023E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B20017A_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017A_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B20017B_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017B_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B19013_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19013_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B25077_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B25077_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S2301_C04_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S2301_C04_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0046PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0046PE", "ucgid" => "pseudo(0100000US\$0500000)")
#
# C24060_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# C24060_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B22002_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B22002_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B22002_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_003E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B22001_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22001_003E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B28002_013E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_013E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B28002_004E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_004E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B28010_005E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28010_005E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0058E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0058E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0073PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0073PE", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0074E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0074E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_045E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_045E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_013E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_013E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_009E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_009E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_010E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_010E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_011E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_011E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S0801_C01_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# H2_003N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_003N", "ucgid" => "pseudo(0100000US\$0500000)")
#
# H2_002N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_002N", "ucgid" => "pseudo(0100000US\$0500000)")
#
# H2_001N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_001N", "ucgid" => "pseudo(0100000US\$0500000)")
# "raw_data/census/census_data_county_raw.csv"

# %%
dfs = [
    [query_census(surv_acs, var, agg="zip code tabulation area")[!, ["ucgid", "NAME", var]] for (_, var) in vars_acs];
    [query_census(surv_dec, var, agg="zip code tabulation area")[!, ["ucgid", "NAME", var]] for (_, var) in vars_dec]
]

df = dfs[1]
for next_df in dfs[2:end]
    leftjoin!(df, next_df, on=["NAME", "ucgid"])
end

fname = "raw_data/census/census_data_zcta_raw.csv"
CSV.write(fname, df)
# Out:
# B01001_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B01001_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B11005_006E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_006E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B11005_007E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_007E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B11005_008E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_008E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B11005_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_002E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B14005_012E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_012E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B14005_026E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_026E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B14005_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B20001_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_002E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B20001_023E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_023E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B20017A_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017A_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B20017B_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017B_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B19013_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19013_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B25077_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B25077_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S2301_C04_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S2301_C04_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# DP04_0046PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0046PE", "ucgid" => "pseudo(0100000US\$8600000)")
#
# C24060_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_002E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# C24060_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B22002_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B22002_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_002E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B22002_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_003E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B22001_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22001_003E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B28002_013E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_013E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B28002_004E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_004E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# B28010_005E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28010_005E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# DP04_0058E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0058E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# DP04_0073PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0073PE", "ucgid" => "pseudo(0100000US\$8600000)")
#
# DP04_0074E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0074E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_045E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_045E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_013E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_013E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_009E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_009E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_010E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_010E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_011E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_011E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# S0801_C01_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_001E", "ucgid" => "pseudo(0100000US\$8600000)")
#
# H2_003N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_003N", "ucgid" => "pseudo(0100000US\$8600000)")
#
# H2_002N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_002N", "ucgid" => "pseudo(0100000US\$8600000)")
#
# H2_001N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_001N", "ucgid" => "pseudo(0100000US\$8600000)")
# "raw_data/census/census_data_zcta_raw.csv"

# %%
dfs = [
    [query_census(surv_acs, var, agg="tract")[!, ["ucgid", "NAME", var]] for (_, var) in vars_acs];
    [query_census(surv_dec, var, agg="tract")[!, ["ucgid", "NAME", var]] for (_, var) in vars_dec]
]

df = dfs[1]
for next_df in dfs[2:end]
    leftjoin!(df, next_df, on=["NAME", "ucgid"])
end

fname = "raw_data/census/census_data_tract_raw.csv"
CSV.write(fname, df)
# Out:
# B01001_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B01001_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_006E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_006E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_007E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_007E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_008E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_008E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B14005_012E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_012E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B14005_026E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_026E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B14005_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B14005_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B20001_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B20001_023E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20001_023E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B20017A_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017A_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B20017B_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B20017B_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B19013_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19013_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B25077_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B25077_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S2301_C04_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S2301_C04_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0046PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0046PE", "ucgid" => "pseudo(0100000US\$1400000)")
#
# C24060_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# C24060_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B22002_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B22002_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B22002_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22002_003E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B22001_003E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B22001_003E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B28002_013E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_013E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B28002_004E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28002_004E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B28010_005E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B28010_005E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0058E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0058E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0073PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0073PE", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0074E
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0074E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_045E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_045E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_013E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_013E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_009E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_009E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_010E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_010E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_011E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_011E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# S0801_C01_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S0801_C01_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# H2_003N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_003N", "ucgid" => "pseudo(0100000US\$1400000)")
#
# H2_002N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_002N", "ucgid" => "pseudo(0100000US\$1400000)")
#
# H2_001N
# https://api.census.gov/data/2020/dec/dhc
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,H2_001N", "ucgid" => "pseudo(0100000US\$1400000)")
# SystemError: opening file "raw_data/census/census_data_tract_raw.csv": Permission denied
#
# Stacktrace:
#   [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#     @ Base .\error.jl:176
#   [2] systemerror
#     @ .\error.jl:175 [inlined]
#   [3] open(fname::String; lock::Bool, read::Nothing, write::Nothing, create::Nothing, truncate::Bool, append::Nothing)
#     @ Base .\iostream.jl:293
#   [4] open
#     @ .\iostream.jl:275 [inlined]
#   [5] open(fname::String, mode::String; lock::Bool)
#     @ Base .\iostream.jl:356
#   [6] open(fname::String, mode::String)
#     @ Base .\iostream.jl:355
#   [7] with(f::CSV.var"#107#108"{Bool, Bool, Tables.Schema{(:ucgid, :NAME, :B01001_001E, :B11005_006E, :B11005_007E, :B11005_008E, :B11005_002E, :B14005_012E, :B14005_026E, :B14005_001E, :B20001_002E, :B20001_023E, :B20017A_001E, :B20017B_001E, :B19013_001E, :B25077_001E, :S2301_C04_001E, :DP04_0046PE, :C24060_002E, :C24060_001E, :B22002_001E, :B22002_002E, :B22002_003E, :B22001_003E, :B28002_013E, :B28002_004E, :B28010_005E, :DP04_0058E, :DP04_0073PE, :DP04_0074E, :S0801_C01_045E, :S0801_C01_013E, :S0801_C01_009E, :S0801_C01_010E, :S0801_C01_011E, :S0801_C01_001E, :H2_003N, :H2_002N, :H2_001N), Tuple{String, String, String, Vararg{Union{Missing, String}, 36}}}, DataFrames.DataFrameRows{DataFrame}, CSV.Options{UInt8, UInt8, Nothing, Tuple{}, typeof(CSV._identity)}, Vector{UInt8}, Int64, Int64, NTuple{39, Symbol}}, io::Any, append::Bool, compress::Bool)
#     @ CSV C:\Users\hmills1\.julia\packages\CSV\XLcqT\src\write.jl:286
#   [8] #write#106
#     @ C:\Users\hmills1\.julia\packages\CSV\XLcqT\src\write.jl:215 [inlined]
#   [9] write(file::String, itr::DataFrame; append::Bool, compress::Bool, writeheader::Nothing, partition::Bool, kw::@Kwargs{})
#     @ CSV C:\Users\hmills1\.julia\packages\CSV\XLcqT\src\write.jl:199
#  [10] write(file::String, itr::DataFrame)
#     @ CSV C:\Users\hmills1\.julia\packages\CSV\XLcqT\src\write.jl:162
#  [11] top-level scope
#     @ In[6]:12

# %%
surv_acs = "2023/acs/acs5"
vars = [
    ("B19013_001E" => "MedHHInc")
    ("B19054_002E" => "PctRecvIDR_num")
    ("B19054_001E" => "PctRecvIDR_den")
    ("B19058_002E" => "PctPubAsst_num")
    ("B19058_001E" => "PctPubAsst_den")
    ("B25077_001E" => "MedHomeVal")
    ("C24060_002E" => "PctMgmtBusScArti_num")
    ("C24060_001E" => "PctMgmtBusScArti_den")
    ("B11005_007E" => "PctFemHeadKids_num1")
    ("B11005_010E" => "PctFemHeadKids_num2")
    ("B11005_001E" => "PctFemHeadKids_den")
    ("DP04_0046PE" => "PctOwnerOcc")
    ("DP04_0075PE" => "PctNoPhone")
    ("DP04_0073PE" => "PctNComPlmb")
    ("S1501_C01_009E" => "PctEduc_num25upHS")
    ("S1501_C01_010E" => "PctEduc_num25upSC")
    ("S1501_C01_011E" => "PctEduc_num25upAD")
    ("S1501_C01_012E" => "PctEduc_num25upBD")
    ("S1501_C01_013E" => "PctEduc_num25upGD")
    ("S1501_C01_006E" => "PctEduc_den25up")
    ("S1702_C02_001E" => "PctFamBelowPov")
    ("S2301_C04_001E" => "PctUnempl")
    ("B01001_001E" => "TotalPopulation")
]

dfs = [query_census(surv_acs, var, agg="county")[!, ["ucgid", "NAME", var]] for (var, _) in vars]
;
# Out:
# B19013_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19013_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B19054_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19054_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B19054_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19054_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B19058_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19058_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B19058_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19058_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B25077_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B25077_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# C24060_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_002E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# C24060_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_007E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_007E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_010E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_010E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B11005_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0046PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0046PE", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0075PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0075PE", "ucgid" => "pseudo(0100000US\$0500000)")
#
# DP04_0073PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0073PE", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_009E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_009E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_010E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_010E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_011E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_011E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_012E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_012E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_013E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_013E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1501_C01_006E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1501_C01_006E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S1702_C02_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S1702_C02_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# S2301_C04_001E
# https://api.census.gov/data/2023/acs/acs5/subject
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,S2301_C04_001E", "ucgid" => "pseudo(0100000US\$0500000)")
#
# B01001_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B01001_001E", "ucgid" => "pseudo(0100000US\$0500000)")

# %%
df = dfs[1]
for next_df in dfs[2:end]
    leftjoin!(df, next_df, on=["NAME", "ucgid"])
end

fname = "raw_data/census/census_data_ndi_county_raw.csv"
CSV.write(fname, df)
# Out:
# "raw_data/census/census_data_ndi_county_raw.csv"

# %%
fname = "raw_data/census/census_data_ndi_county_raw.csv"
df = DataFrame(CSV.File(fname));

# %%
rename!(df, vars);

# %%
function fix(s)
    if s in [-666666666, -999999999, -888888888, -222222222, -333333333, -555555555,
             "-666666666", "-999999999", "-888888888", "-222222222", "-333333333", "-555555555",
             "Varies", "*", "null"]
        return NaN
    elseif typeof(s) == String
        return parse(Float64, s)
    else
        return s
    end
end
        
    
for (_, name) in vars
    df[!, name] = [fix(e) for e in df[!, name]]
end

# %%
df[!, "PctRecvIDR"] = 100 * df[!, "PctRecvIDR_num"] ./ df[!, "PctRecvIDR_den"]
df[!, "PctPubAsst"] = 100 * df[!, "PctPubAsst_num"] ./ df[!, "PctPubAsst_den"]
df[!, "PctMgmtBusSciArt"] = 100 * df[!, "PctMgmtBusScArti_num"] ./ df[!, "PctMgmtBusScArti_den"]
df[!, "PctFemHeadKids"] = 100 * (df[!, "PctFemHeadKids_num1"] + df[!, "PctFemHeadKids_num2"]) ./ df[!, "PctFemHeadKids_den"]
df[!, "PctEducHSPlus"] = (df[!, "PctEduc_num25upHS"] .+ df[!, "PctEduc_num25upSC"] .+ df[!, "PctEduc_num25upAD"] \
                       .+ df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"] * 100
df[!, "PctEducBchPlus"] = 100 * (df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"]

df[!, "PctRecvIDR"] = 100 * df[!, "PctRecvIDR_num"] ./ df[!, "PctRecvIDR_den"]
df[!, "PctPubAsst"] = 100 * df[!, "PctMgmtBusScArti_num"] ./ df[!, "PctMgmtBusScArti_den"]
df[!, "PctFemHeadKids"] = 100 * (df[!, "PctFemHeadKids_num1"] + df[!, "PctFemHeadKids_num2"]) ./ df[!, "PctFemHeadKids_den"]
df[!, "PctEducHSPlus"] = (df[!, "PctEduc_num25upHS"] .+ df[!, "PctEduc_num25upSC"] .+ df[!, "PctEduc_num25upAD"] \
                       .+ df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"] * 100
df[!, "PctEducBchPlus"] = 100 * (df[!, "PctEduc_num25upBD"] + df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"]

df[!, "PctNoIDR"] = 100 .- df[!, "PctRecvIDR"]
df[!, "PctWorkClass"] = 100 .- df[!, "PctMgmtBusSciArt"]
df[!, "PctNotOwnerOcc"] = 100 .- df[!, "PctOwnerOcc"]
df[!, "PctEducLTHS"] = 100 .- df[!, "PctEducHSPlus"]
df[!, "PctEducLTBch"] = 100 .- df[!, "PctEducBchPlus"]

#df[!, "logMedHHInc"] = log.(df[!, "MedHHInc"])
#df[!, "logMedHomeVal"] = log.(df[!, "MedHomeVal"])
;

# %%
cols = ["ucgid",
        "NAME",
        "MedHHInc",
        "PctNoIDR",
        "PctPubAsst",
        "MedHomeVal",
        "PctWorkClass",
        "PctFemHeadKids",
        "PctNotOwnerOcc",
        "PctNoPhone",
        "PctNComPlmb",
        "PctEducLTHS",
        "PctEducLTBch",
        "PctFamBelowPov",
        "PctUnempl",
        "TotalPopulation"]


fname = "raw_data/census/census_data_ndi_county.csv"
CSV.write(fname, df[!, cols])
# Out:
# "raw_data/census/census_data_ndi_county.csv"

# %%
dfs = [query_census(surv_acs, var, agg="tract")[!, ["ucgid", "NAME", var]] for (var, _) in vars]
# Out:
# B19013_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19013_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B19054_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19054_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B19054_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19054_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B19058_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19058_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B19058_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B19058_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B25077_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B25077_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# C24060_002E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_002E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# C24060_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,C24060_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_007E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_007E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_010E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_010E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# B11005_001E
# https://api.census.gov/data/2023/acs/acs5
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,B11005_001E", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0046PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0046PE", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0075PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME,DP04_0075PE", "ucgid" => "pseudo(0100000US\$1400000)")
#
# DP04_0073PE
# https://api.census.gov/data/2023/acs/acs5/profile
# Dict("key" => "0da2f8145563d27c239d445d96e744bead4b7880", "get" => "NAME
#      4 │ 1400000US01001020400  Census Tract 204; Autauga County…  3913
#      5 │ 1400000US01001020501  Census Tract 205.01; Autauga Cou…  4053
#      6 │ 1400000US01001020502  Census Tract 205.02; Autauga Cou…  3514
#      7 │ 1400000US01001020503  Census Tract 205.03; Autauga Cou…  3493
#      8 │ 1400000US01001020600  Census Tract 206; Autauga County…  3658
#      9 │ 1400000US01001020700  Census Tract 207; Autauga County…  2815
#     10 │ 1400000US01001020801  Census Tract 208.01; Autauga Cou…  3431
#     11 │ 1400000US01001020803  Census Tract 208.03; Autauga Cou…  4540
#    ⋮   │          ⋮                            ⋮                       ⋮
#  85372 │ 1400000US72153750102  Census Tract 7501.02; Yauco Muni…  3473
#  85373 │ 1400000US72153750201  Census Tract 7502.01; Yauco Muni…  2220
#  85374 │ 1400000US72153750202  Census Tract 7502.02; Yauco Muni…  3363
#  85375 │ 1400000US72153750300  Census Tract 7503; Yauco Municip…  3971
#  85376 │ 1400000US72153750400  Census Tract 7504; Yauco Municip…  3225
#  85377 │ 1400000US72153750501  Census Tract 7505.01; Yauco Muni…  4170
#  85378 │ 1400000US72153750502  Census Tract 7505.02; Yauco Muni…  2338
#  85379 │ 1400000US72153750503  Census Tract 7505.03; Yauco Muni…  1825
#  85380 │ 1400000US72153750601  Census Tract 7506.01; Yauco Muni…  4747
#  85381 │ 1400000US72153750602  Census Tract 7506.02; Yauco Muni…  2022
#                                                             85360 rows omitted

# %%
df = dfs[1]
for next_df in dfs[2:end]
    leftjoin!(df, next_df, on=["NAME", "ucgid"])
end

fname = "raw_data/census/census_data_ndi_tract_raw.csv"
CSV.write(fname, df[!, cols])
# Out:
# ArgumentError: column name :MedHHInc not found in the data frame
#
# Stacktrace:
#   [1] lookupname
#     @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:431 [inlined]
#   [2] getindex
#     @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:440 [inlined]
#   [3] getindex
#     @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:441 [inlined]
#   [4] (::DataFrames.var"#35#36"{DataFrames.Index})(i::String)
#     @ DataFrames .\none:0
#   [5] iterate
#     @ .\generator.jl:47 [inlined]
#   [6] collect_to!
#     @ .\array.jl:892 [inlined]
#   [7] collect_to_with_first!
#     @ .\array.jl:870 [inlined]
#   [8] collect(itr::Base.Generator{Vector{String}, DataFrames.var"#35#36"{DataFrames.Index}})
#     @ Base .\array.jl:844
#   [9] getindex
#     @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:446 [inlined]
#  [10] getindex(df::DataFrame, row_ind::typeof(!), col_inds::Vector{String})
#     @ DataFrames C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\dataframe\dataframe.jl:631
#  [11] top-level scope
#     @ In[32]:7

# %%
fname = "raw_data/census/census_data_ndi_tract_raw.csv"
df = DataFrame(CSV.File(fname));

# %%
rename!(df, vars);

for (_, name) in vars
    df[!, name] = [fix(e) for e in df[!, name]]
end
# Out:
# ArgumentError: Tried renaming :B19013_001E to :MedHHInc, when :B19013_001E does not exist in the data frame.
#
# Stacktrace:
#  [1] rename!(x::DataFrames.Index, nms::Vector{Pair{Symbol, Symbol}})
#    @ DataFrames C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:91
#  [2] rename!(df::DataFrame, args::Vector{Pair{String, String}})
#    @ DataFrames C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\abstractdataframe\abstractdataframe.jl:241
#  [3] top-level scope
#    @ In[34]:1

# %%
df[!, "PctRecvIDR"] = 100 * df[!, "PctRecvIDR_num"] ./ df[!, "PctRecvIDR_den"]
df[!, "PctPubAsst"] = 100 * df[!, "PctPubAsst_num"] ./ df[!, "PctPubAsst_den"]
df[!, "PctMgmtBusSciArt"] = 100 * df[!, "PctMgmtBusScArti_num"] ./ df[!, "PctMgmtBusScArti_den"]
df[!, "PctFemHeadKids"] = 100 * (df[!, "PctFemHeadKids_num1"] + df[!, "PctFemHeadKids_num2"]) ./ df[!, "PctFemHeadKids_den"]
df[!, "PctEducHSPlus"] = (df[!, "PctEduc_num25upHS"] .+ df[!, "PctEduc_num25upSC"] .+ df[!, "PctEduc_num25upAD"] \
                       .+ df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"] * 100
df[!, "PctEducBchPlus"] = 100 * (df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"]

df[!, "PctRecvIDR"] = 100 * df[!, "PctRecvIDR_num"] ./ df[!, "PctRecvIDR_den"]
df[!, "PctPubAsst"] = 100 * df[!, "PctMgmtBusScArti_num"] ./ df[!, "PctMgmtBusScArti_den"]
df[!, "PctFemHeadKids"] = 100 * (df[!, "PctFemHeadKids_num1"] + df[!, "PctFemHeadKids_num2"]) ./ df[!, "PctFemHeadKids_den"]
df[!, "PctEducHSPlus"] = (df[!, "PctEduc_num25upHS"] .+ df[!, "PctEduc_num25upSC"] .+ df[!, "PctEduc_num25upAD"] \
                       .+ df[!, "PctEduc_num25upBD"] .+ df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"] * 100
df[!, "PctEducBchPlus"] = 100 * (df[!, "PctEduc_num25upBD"] + df[!, "PctEduc_num25upGD"]) ./ df[!, "PctEduc_den25up"]

df[!, "PctNoIDR"] = 100 .- df[!, "PctRecvIDR"]
df[!, "PctWorkClass"] = 100 .- df[!, "PctMgmtBusSciArt"]
df[!, "PctNotOwnerOcc"] = 100 .- df[!, "PctOwnerOcc"]
df[!, "PctEducLTHS"] = 100 .- df[!, "PctEducHSPlus"]
df[!, "PctEducLTBch"] = 100 .- df[!, "PctEducBchPlus"]
# Out:
# ArgumentError: column name :PctRecvIDR_num not found in the data frame
#
# Stacktrace:
#  [1] lookupname
#    @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:431 [inlined]
#  [2] getindex
#    @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:440 [inlined]
#  [3] getindex
#    @ C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\other\index.jl:441 [inlined]
#  [4] getindex(df::DataFrame, ::typeof(!), col_ind::String)
#    @ DataFrames C:\Users\hmills1\.julia\packages\DataFrames\kcA9R\src\dataframe\dataframe.jl:557
#  [5] top-level scope
#    @ In[35]:1

# %%
cols = ["ucgid",
        "NAME",
        "MedHHInc",
        "PctNoIDR",
        "PctPubAsst",
        "MedHomeVal",
        "PctWorkClass",
        "PctFemHeadKids",
        "PctNotOwnerOcc",
        "PctNoPhone",
        "PctNComPlmb",
        "PctEducLTHS",
        "PctEducLTBch",
        "PctFamBelowPov",
        "PctUnempl",
        "TotalPopulation"]


fname = "raw_data/census/census_data_ndi_tract.csv"
CSV.write(fname, df[!, cols])
# Out:
# "raw_data/census/census_data_ndi_tract.csv"
